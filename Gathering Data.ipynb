# %% [markdown]
# ## Import Songs

# %%
import pandas as pd
import numpy as np
import re

# %%
## Data gathered from https://components.one/datasets/billboard-200/
songs = pd.read_csv('./data/acoustic_features.csv')
albums = pd.read_csv('./data/albums.csv')
top100 = pd.read_csv('./data/top100_by_year.csv').iloc[:, 1:]

# %%
songs.head()
# Out:
#                        id                                song       album  \
# 0  0Veyvc3n9AcLSoK3r1dA12                   Voices In My Head  Hoodie SZN
# 1  77JzXZonNumWsuXKy9vr3U                              Beasty  Hoodie SZN
# 2  18yllZD0TdF7ykcREib8Z1                            I Did It  Hoodie SZN
# 3  1wJRveJZLSb1rjhnUHQiv6             Swervin (feat. 6ix9ine)  Hoodie SZN
# 4  0jAfdqv18goRTUxm3ilRjb  Startender (feat. Offset and Tyga)  Hoodie SZN
#
#                    artist  acousticness  danceability  duration_ms  energy  \
# 0  A Boogie Wit da Hoodie        0.0555         0.754     142301.0   0.663
# 1  A Boogie Wit da Hoodie        0.2920         0.860     152829.0   0.418
# 2  A Boogie Wit da Hoodie        0.1530         0.718     215305.0   0.454
# 3  A Boogie Wit da Hoodie        0.0153         0.581     189487.0   0.662
# 4  A Boogie Wit da Hoodie        0.0235         0.736     192779.0   0.622
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000000  6.0     0.101    -6.311   0.0        0.427   90.195
# 1          0.000000  7.0     0.106    -9.061   0.0        0.158  126.023
# 2          0.000046  8.0     0.116    -9.012   1.0        0.127   89.483
# 3          0.000000  9.0     0.111    -5.239   1.0        0.303   93.023
# 4          0.000000  6.0     0.151    -4.653   0.0        0.133  191.971
#
#    time_signature  valence                album_id        date
# 0             4.0    0.207  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 1             4.0    0.374  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 2             4.0    0.196  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 3             4.0    0.434  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21
# 4             4.0    0.506  3r5hf3Cj3EMh1C2saQ8jyt  2018-12-21

# %%
#340,000 songs/observations
songs.shape
# Out:
# (339855, 19)

# %%
##Convert date to year
songs['date'] = pd.to_datetime(songs['date'])
songs['year'] = songs['date'].dt.year
songs.drop(columns=['album', 'album_id', 'date'], inplace=True)

# %%
##Drop songs that are newer than 2015 (the top 100 dataset only goes up to 2015)
new_songs = songs[songs['year']>2015]
songs.drop(new_songs.index, inplace=True)

# %%
## Top 100 by Year looks good, but we need to give each observation a song ID
## So that we can compare with the larger song table
top100[top100['Year']==1965].head()
# Out:
#                                        Song Title  \
# 1080                                  Wooly Bully
# 1081  I Can't Help Myself (Sugar Pie Honey Bunch)
# 1082                (I Can't Get No) Satisfaction
# 1083                          You Were On My Mind
# 1084              You've Lost That Lovin' Feelin'
#
#                              Artist  Year  Position
# 1080  Sam The Sham and The Pharaohs  1965         1
# 1081                      Four Tops  1965         2
# 1082                 Rolling Stones  1965         3
# 1083                        We Five  1965         4
# 1084             Righteous Brothers  1965         5

# %% [markdown]
# ## Spotify

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2

market = [ "AD", "AR", "AT", "AU", "BE", "BG", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", 
      "CZ", "DE", "DK", "DO", "EC", "EE", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", 
      "ID", "IE", "IS", "IT", "JP", "LI", "LT", "LU", "LV", "MC", "MT", "MX", "MY", "NI", "NL", 
      "NO", "NZ", "PA", "PE", "PH", "PL", "PT", "PY", "SE", "SG", "SK", "SV", "TH", "TR", "TW", 
      "US", "UY", "VN" ]

CLIENT_ID = "07663e5a63794b58b412cdbe45565d1a"
CLIENT_SECRET = "991bcea116134ab29fe3793adb25b648"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
sp = spotipy.Spotify(auth=token)

# %%
## Going to use NLTK to clean up each song's title and artist to make it easier to search with the Spotify API
# Load library
from nltk.corpus import stopwords

# You will have to download the set of stop words the first time
import nltk
nltk.download('stopwords')

# Load stop words
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jcacho/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## This function will clean the song titles and artist names, 
## removing non-alphanumeric characters and things like featured artists
def clean_text(text):
    #Make lower-case
    text = text.lower()
    #Keep only the first name if there are two names separated by forward-slash
    if text.find('/') > 0:
        delimiter = text.find('/')
        text = text[:delimiter-1]
    if text.find('feat')>0:
        delimiter = text.find('feat')
        text = text[:delimiter-1]
    #Remove non-alphanumeric characters
    text = re.sub(r'([^\s\w]|_)+', '', text)
    #Remove stop-words
    tokenized_name = text.split(" ")
    filtered_tokens = [word for word in tokenized_name if word not in stop_words and len(word)>1]
    text = " ".join(filtered_tokens)
    return text

# %%
## Testing the function
clean_text('Post To Be | Omarion feat. Chris Brown and Jhe')
# Out:
# 'post omarion'

# %%
## This query will use different variations of the song name and artist name to query the Spotify API and
## increase the likelihood of obtaining the correct song
def get_song_details(query):
    song_name = query.split('|')[0]
    song_name = clean_text(song_name)
    try:
        artist = query.split('|')[1]
        artist = clean_text(artist)
    except:
        artist = ""

    try:
        results = sp.search(q=query, type='track')
        artist = results['tracks']['items'][0]['artists'][0]['name']
        song_name = results['tracks']['items'][0]['name']
        song_id = results['tracks']['items'][0]['id']
        return artist, song_name, song_id
    except:
        try:
            results = sp.search(q=clean_name+" "+artist, type='track')
            artist = results['tracks']['items'][0]['artists'][0]['name']
            song_name = results['tracks']['items'][0]['name']
            song_id = results['tracks']['items'][0]['id']
            return artist, song_name, song_id
        except:
            try:
                results = sp.search(q=song_name, type='track')
                artist = results['tracks']['items'][0]['artists'][0]['name']
                song_name = results['tracks']['items'][0]['name']
                song_id = results['tracks']['items'][0]['id']
                return artist, song_name, song_id
            except:
                try:
                    results = sp.search(q=short_name, type='track')
                    artist = results['tracks']['items'][0]['artists'][0]['name']
                    song_name = results['tracks']['items'][0]['name']
                    song_id = results['tracks']['items'][0]['id']
                    return artist, song_name, song_id
                except:
                    return np.nan

# %%
## Testing the function
get_song_details('post omarion')
# Out:
# ('Omarion',
#  'Post to Be (feat. Chris Brown & Jhene Aiko)',
#  '0fgZUSa7D7aVvv3GfO0A1n')

# %%
## Testing the function
get_song_details("sugar shack jimmy")
# Out:
# ('Jimmy Gilmer & The Fireballs', 'Sugar Shack', '2nLLenueHlqs60IcDn9lan')

# %% [markdown]
# ### Now lets add Song ID to our Top100 dataframe

# %%
## Removing songs from prior to 1963 because our larger song dataset starts at 1963
top100 = top100[top100['Year'] > 1962]
top100.shape
# Out:
# (5300, 4)

# %%
## Reset index after removals
top100.reset_index(drop=True, inplace=True)

# %%
top100.head()
# Out:
#              Song Title                          Artist  Year  Position
# 0           Sugar Shack  Jimmy Gilmer and The Fireballs  1963         1
# 1        Surfin' U.S.A.                      Beach Boys  1963         2
# 2  The End Of The World                   Skeeter Davis  1963         3
# 3    Rhythm Of The Rain                        Cascades  1963         4
# 4          He's So Fine                        Chiffons  1963         5

# %%
## Testing get_song_details
get_song_details(top100['Song Title'][5223] + " | " + top100['Artist'][5223])
# Out:
# ('Omarion',
#  'Post to Be (feat. Chris Brown & Jhene Aiko)',
#  '0fgZUSa7D7aVvv3GfO0A1n')

# %%
## Grabbing the acoustic features of that particular song (test)
pd.DataFrame(sp.audio_features('0fgZUSa7D7aVvv3GfO0A1n'))
# Out:
#    acousticness                                       analysis_url  \
# 0        0.0697  https://api.spotify.com/v1/audio-analysis/0fgZ...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.733       226581   0.676  0fgZUSa7D7aVvv3GfO0A1n
#
#    instrumentalness  key  liveness  loudness  mode  speechiness   tempo  \
# 0                 0   10     0.208    -5.655     0       0.0432  97.448
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/0fgZUSa7D7aV...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:0fgZUSa7D7aVvv3GfO0A1n    0.701

# %%
top100['Song Title'][5223] + " " + top100['Artist'][5223]
# Out:
# 'Post To Be Omarion feat. Chris Brown and Jhene Aiko'

# %%
top100['Query'] = top100['Song Title'] + " | " + top100['Artist']

# %%
top100[top100['Artist']=='Omarion feat. Chris Brown and Jhene Aiko']['Query']
# Out:
# 5223    Post To Be | Omarion feat. Chris Brown and Jhe...
# Name: Query, dtype: object

# %%
test_df = top100[5247:5296]

# %%
test_df.head()
# Out:
#                       Song Title  \
# 5247  B**** Better Have My Money
# 5248          Flex (Ooh Ooh Ooh)
# 5249             Nasty Freestyle
# 5250                        Only
# 5251               Elastic Heart
#
#                                                  Artist  Year  Position  \
# 5247                                            Rihanna  2015        48
# 5248                                    Rich Homie Quan  2015        49
# 5249                                            T-Wayne  2015        50
# 5250  Nicki Minaj feat. Drake, Lil Wayne and Chris B...  2015        51
# 5251                                                Sia  2015        52
#
#                                                   Query
# 5247               B**** Better Have My Money | Rihanna
# 5248               Flex (Ooh Ooh Ooh) | Rich Homie Quan
# 5249                          Nasty Freestyle | T-Wayne
# 5250  Only | Nicki Minaj feat. Drake, Lil Wayne and ...
# 5251                                Elastic Heart | Sia

# %%
## Querying the Spotify API for the details of every song in our test_df
test_df[['Spotify Artist', 'Spotify Song', 'Spotify ID']] = test_df['Query'].map(get_song_details).apply(pd.Series)
# Out:
# /Users/jcacho/anaconda3/envs/DSI/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
## Check results
test_df
# Out:
#                          Song Title  \
# 5247     B**** Better Have My Money
# 5248             Flex (Ooh Ooh Ooh)
# 5249                Nasty Freestyle
# 5250                           Only
# 5251                  Elastic Heart
# 5252            Cool For The Summer
# 5253                      Renegades
# 5254                   I Don't Mind
# 5255                 Love Me Harder
# 5256                 Wildest Dreams
# 5257                   Stay With Me
# 5258           You Know You Like It
# 5258  26xFramtAb4oQgOdbyUKwK
# 5259  5PUawWFG1oIS2NwEcyHaCr
# 5260                     NaN
# 5261  2dRvMEW4EwySxRUtEamSfG
# 5262  11qh54D0PKkBwelpDxxiEU
# 5263  4NYwy0R3NdvORX2B6OZXBT
# 5264  2K87XMYnUMqLcX3zvtAF4G
# 5265  0EbR4xHL4XT5o7Ph0gxGsB
# 5266  7xoUc6faLbCqZO6fQEYprd
# 5267  5Eg4TsPcqNbIjd8ADMZosg
# 5268  0hy1SOTEn9ifXTzOwnCwEr
# 5269  4scpF6J5uMBvoh6sFB7EL1
# 5270  3JvrhDOgAt6p7K8mDyZwRd
# 5271  0nMmaCneU4UnTczt7gX3Fy
# 5272  70eDxAyAraNTiD6lx2ZEnH
# 5273  3cU2wBxuV6nFiuf6PJZNlC
# 5274  6ukMqDxnOPOgoHdak7Kyp3
# 5275  2YlZnw2ikdb837oKMKjBkW
# 5276  14OxJlLdcHNpgsm4DRwDOB
# 5277  6TtXgp6quA3jSgBfFTuAUO
# 5278  2JI71GHwq2LN8mtq3iCLYo
# 5279  1z3Q0Vv26kdsSc8KshjNWX
# 5280  64GRDrL1efgXclrhVCeuA0
# 5281  2znzyzlAUc8Z1Ikq9aFOcx
# 5282  4OjuzM3rTWp3q60mEldNSF
# 5283  5pfJsMwoRYKampPay8amX0
# 5284  1TwLKNsCnhi1HxbIi4bAW0
# 5285  6tqd3vtdB96Pw81hjAvWuM
# 5286  5g15o2Sm55Hn9ShK5yEXgp
# 5287  1DJAbruIj7a3U14gRtLLyv
# 5288  7q0aQpiLv5tIsupcgQ3Ny4
# 5289  2s1sdSqGcKxpPr5lCl7jAV
# 5290  7FC9Lng8iXU081lbigu8m8
# 5291  3HVWdVOQ0ZA45FuZGSfvns
# 5292  4z7gh3aIZV9arbL9jJSc5J
# 5293  1wYZZtamWTQAoj8B812uKQ
# 5294  5Sf3GyLEAzJXxZ5mbCPXTu
# 5295  7hOfyNuj2dLc0HAEYVDIYS

# %%
## Now lets try it for real on the top100 dataset
## This can take up to half an hour.
top100[['Spotify Artist', 'Spotify Song', 'Spotify ID']] = top100['Query'].map(get_song_details).apply(pd.Series)
backup_top100 = top100

# %%
# Check for null values (i.e. songs that were not found)
top100[top100['Spotify ID'].isnull()]
# Out:
#                                              Song Title  \
# 491       Little Ole Man (Uptight-Everything's Alright)
# 574                          Shoo-Bee-Doo-Be-Doo-Da-Day
# 718          Thank You (Fallettin Me Be Mice Elf Again)
# 821                         Uncle Albert-Admiral Halsey
# 938                                       Day Atter Day
# 985                        Don't Say You Don't Rememeer
# 997             Walking In The Rain With The One I Love
# 1265                        One Man Woman-One Woman Man
# 1490          Whispering-Cherchez La Femme-C'est Si Bon
# 1960                                   Owe Hundred Ways
# 1963                         You Could Have Been Wih Me
# 2045                 Always Somethmg There To Remind Me
# 2561                                             1/2/03
# 2668                                  Secret Rendesvous
# 2686                               Iwanna Have Some Fun
# 2693                                     Heavan Help Me
# 2862                                   Saideness Part I
# 2979                 Have You Ever Needed Somone So Bad
# 3471       ESPN Presents The Jock Jam | Various Artists            NaN
# 3852         Superwoman Pt. II | Lil' Mo feat. Fabolous            NaN
# 3943  Down 4 U | Irv Gotti Presents The Inc. feat. J...            NaN
# 4156                  Walker outta Heaven | Jagged Edge            NaN
# 4355  Do it to It | Cherish feat. Sean Paul Of The Y...            NaN
# 4399          For You I Will (Condience) | Teddy Geiger            NaN
# 4422  Cupid's Chokehold/Breakfast In America | Gym C...            NaN
# 5260                                   11-Jul | Beyonce            NaN
#
#      Spotify Song Spotify ID
# 491           NaN        NaN
# 574           NaN        NaN
# 718           NaN        NaN
# 821           NaN        NaN
# 938           NaN        NaN
# 985           NaN        NaN
# 997           NaN        NaN
# 1265          NaN        NaN
# 1490          NaN        NaN
# 1960          NaN        NaN
# 1963          NaN        NaN
# 2045          NaN        NaN
# 2561          NaN        NaN
# 2668          NaN        NaN
# 2686          NaN        NaN
# 2693          NaN        NaN
# 2862          NaN        NaN
# 2979          NaN        NaN
# 3028          NaN        NaN
# 3289          NaN        NaN
# 3356          NaN        NaN
# 3471          NaN        NaN
# 3852          NaN        NaN
# 3943          NaN        NaN
# 4156          NaN        NaN
# 4355          NaN        NaN
# 4399          NaN        NaN
# 4422          NaN        NaN
# 5260          NaN        NaN

# %%
## Keep track of songs that weren't found
missing_vals = top100[top100['Spotify ID'].isnull()]

# %%
missing_vals
# Out:
#                                              Song Title  \
# 491       Little Ole Man (Uptight-Everything's Alright)
# 574                          Shoo-Bee-Doo-Be-Doo-Da-Day
# 718          Thank You (Fallettin Me Be Mice Elf Again)
# 821                         Uncle Albert-Admiral Halsey
# 938                                       Day Atter Day
# 985                        Don't Say You Don't Rememeer
# 997             Walking In The Rain With The One I Love
# 1265                        One Man Woman-One Woman Man
# 1490          Whispering-Cherchez La Femme-C'est Si Bon
# 1960                                   Owe Hundred Ways
# 1963                         You Could Have Been Wih Me
# 2045                 Always Somethmg There To Remind Me
# 2561                                             1/2/03
# 2668                                  Secret Rendesvous
# 2686                               Iwanna Have Some Fun
# 2693                                     Heavan Help Me
# 2862                                   Saideness Part I
# 2979                 Have You Ever Needed Somone So Bad
# 3028                 Right Here (Human Nature)-Downtown
# 3289                   Like The Way I Do-If I Wanted To
# 3356  Woo-hah!! Got You All In Check / Everything Re...
# 3471                         ESPN Presents The Jock Jam
# 3852                                  Superwoman Pt. II
# 3943                                           Down 4 U
# 4156                                Walker outta Heaven
# 4355                                        Do it to It
# 4399                         For You I Will (Condience)
# 4422             Cupid's Chokehold/Breakfast In America
# 5260                                             11-Jul
#
#                                                  Artist  Year  Position  \
# 491                                          Bill Cosby  1967        92
# 574                                       Stevie Wonder  1968        75
# 718                            Sly and The Family Stone  1970        19
# 821                            Paul and Linda McCartney  1971        22
# 938                                           Badfinger  1972        39
# 985                                     Beverly Bremers  1972        86
# 997                                      Love Unlimited  1972        98
# 1265                          Paul Anka and Odia Coates  1975        66
# 1490               Dr. Buzzard's Original Savannah Band  1977        91
# 1960                                       Quincy Jones  1982        61
# 1963                                      Sheena Easton  1982        64
# 2045                                         Naked Eyes  1983        46
# 2979          NaN        NaN
# 3028          NaN        NaN
# 3289          NaN        NaN
# 3356          NaN        NaN
# 3471          NaN        NaN
# 3852          NaN        NaN
# 3943          NaN        NaN
# 4156          NaN        NaN
# 4355          NaN        NaN
# 4399          NaN        NaN
# 4422          NaN        NaN
# 5260          NaN        NaN

# %%
## Drop NAs and reset index
top100.dropna(inplace=True)
top100.reset_index(drop=True, inplace=True)
top100.shape
# Out:
# (5271, 8)

# %%
## Let's compare our original song details to the queried song details to make sure we're grabbing the right songs
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
similar('Jimmy Gilmer and The Fireballs', 'Jimmy Gilmer & The Fireballs')
# Out:
# 0.9310344827586207

# %%
top100['Similarity Score'] = similar(top100['Artist'], top100['Spotify Artist'])

# %%
## Checking for mislabeling of observations
for row in range(0, len(top100)):
    try:
        top100.loc[row, 'Similarity Score'] = similar(top100.loc[row, 'Artist'], top100.loc[row,'Spotify Artist'])
    except:
        top100.loc[row, 'Similarity Score'] = np.nan

# %%
top100.head()
# Out:
#              Song Title                          Artist  Year  Position  \
# 0           Sugar Shack  Jimmy Gilmer and The Fireballs  1963         1
# 1        Surfin' U.S.A.                      Beach Boys  1963         2
# 2  The End Of The World                   Skeeter Davis  1963         3
# 3    Rhythm Of The Rain                        Cascades  1963         4
# 4          He's So Fine                        Chiffons  1963         5
#
#                                           Query                Spotify Artist  \
# 0  Sugar Shack | Jimmy Gilmer and The Fireballs  Jimmy Gilmer & The Fireballs
# 1                   Surfin' U.S.A. | Beach Boys                The Beach Boys
# 2          The End Of The World | Skeeter Davis                 Skeeter Davis
# 3                 Rhythm Of The Rain | Cascades                  The Cascades
# 4                       He's So Fine | Chiffons                  The Chiffons
#
#                      Spotify Song              Spotify ID  Similarity Score
# 0                     Sugar Shack  2nLLenueHlqs60IcDn9lan          0.931034
# 1     Surfin' U.S.A. - Remastered  0wz1LjDb9ZNEYwOmDJ3Q4b          0.833333
# 2            The End of the World  5DTOOkooKFUvWj1XQTFa09          1.000000
# 3              Rhythm Of The Rain  7GHf8dQ2wA71wYOuRsQCZP          0.800000
# 4  He's So Fine - Remastered 2000  2Bs1Lw9LX8hBm70t1iGdlh          0.800000

# %%
top100.tail()
# Out:
#                    Song Title                          Artist  Year  Position  \
# 5266  El Perdon (Forgiveness)  Nicky Jam and Enrique Iglesias  2015        96
# 5267                She Knows             Ne-Yo feat. Juicy J  2015        97
# 5268            Night Changes                   One Direction  2015        98
# 5269             Back To Back                           Drake  2015        99
# 5270    How Deep Is Your Love     Calvin Harris and Disciples  2015       100
#
#                                                   Query Spotify Artist  \
# 5266  El Perdon (Forgiveness) | Nicky Jam and Enriqu...      Nicky Jam
# 5267                    She Knows | Ne-Yo feat. Juicy J  Backing Force
# 5268                      Night Changes | One Direction  One Direction
# 5269                               Back To Back | Drake          Drake
# 5270  How Deep Is Your Love | Calvin Harris and Disc...  Calvin Harris
#
#                                            Spotify Song  \
# 5266                            El Perdón - Forgiveness
# 5267  She Knows (Originally Performed by Ne-yo feat....
# 5268                                      Night Changes
# 5269                                       Back To Back
# 5270  How Deep Is Your Love - Calvin Harris & R3hab ...
#
#                   Spotify ID  Similarity Score
# 5266  7hOfyNuj2dLc0HAEYVDIYS          0.461538
# 5267  6UkElkPH4OGwh43eOTusZf          0.062500
# 5268  5O2P9iiztwhomNh8xkR9lJ          1.000000
# 5269  5lFDtgWsjRJu8fPOAyJIAK          1.000000
# 5270  6rMwYjoFvxKiaEH4If8ZpZ          0.650000

# %%
##Drop all songs that are karaoke versions
karaoke_songs = top100[top100['Spotify Artist'].str.contains('Karaoke')].index
top100.drop(karaoke_songs, inplace=True)

# %%
## 0.3 similarity score seems to be a good cut-off for songs that should be discarded
diff_names = top100[(top100['Similarity Score']<0.3) | (top100['Similarity Score'].isna())]
top100.drop(diff_names.index, inplace=True)

# %%
top100.shape
# Out:
# (4745, 9)

# %%
top100.reset_index(drop=True, inplace=True)

# %%
## Now lets grab the acoustic features of each song in our top100 dataset
top100_id = top100['Spotify ID']
audio_features = pd.DataFrame()
for song_id in top100_id:
    features = pd.DataFrame(sp.audio_features(song_id))
    audio_features = audio_features.append(features, ignore_index=True)
# Out:
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...1secs
# /Users/jcacho/anaconda3/envs/DSI/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
# Check results...
audio_features.head()
# Out:
#      0  acousticness                                       analysis_url  \
# 0  NaN         0.225  https://api.spotify.com/v1/audio-analysis/2nLL...
# 1  NaN         0.661  https://api.spotify.com/v1/audio-analysis/0wz1...
# 2  NaN         0.936  https://api.spotify.com/v1/audio-analysis/5DTO...
# 3  NaN         0.627  https://api.spotify.com/v1/audio-analysis/7GHf...
# 4  NaN         0.487  https://api.spotify.com/v1/audio-analysis/2Bs1...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.792     123693.0   0.804  2nLLenueHlqs60IcDn9lan
# 1         0.550     149373.0   0.854  0wz1LjDb9ZNEYwOmDJ3Q4b
# 2         0.232     157573.0   0.216  5DTOOkooKFUvWj1XQTFa09
# 3         0.659     146360.0   0.660  7GHf8dQ2wA71wYOuRsQCZP
# 4         0.558     112520.0   0.633  2Bs1Lw9LX8hBm70t1iGdlh
#
#    instrumentalness   key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000005   7.0     0.065    -7.484   1.0       0.0659  132.852
# 1          0.000000   3.0     0.112    -5.968   1.0       0.0360  159.231
# 2          0.000005  10.0     0.246   -10.674   1.0       0.0314   94.268
# 3          0.000217   0.0     0.136    -8.337   1.0       0.0441  116.634
# 4          0.000000   7.0     0.129    -3.265   1.0       0.0329   72.494
#
#    time_signature                                         track_href  \
# 0             4.0  https://api.spotify.com/v1/tracks/2nLLenueHlqs...
# 1             4.0  https://api.spotify.com/v1/tracks/0wz1LjDb9ZNE...
# 2             3.0  https://api.spotify.com/v1/tracks/5DTOOkooKFUv...
# 3             4.0  https://api.spotify.com/v1/tracks/7GHf8dQ2wA71...
# 4             4.0  https://api.spotify.com/v1/tracks/2Bs1Lw9LX8hB...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:2nLLenueHlqs60IcDn9lan    0.879
# 1  audio_features  spotify:track:0wz1LjDb9ZNEYwOmDJ3Q4b    0.965
# 2  audio_features  spotify:track:5DTOOkooKFUvWj1XQTFa09    0.432
# 3  audio_features  spotify:track:7GHf8dQ2wA71wYOuRsQCZP    0.672
# 4  audio_features  spotify:track:2Bs1Lw9LX8hBm70t1iGdlh    0.871

# %%
## Merge the top 100 acoustic features with the original top100 dataset
top100_details = pd.merge(top100, audio_features, left_on="Spotify ID", right_on="id")
top100_details.head()
# Out:
#              Song Title                          Artist  Year  Position  \
# 0           Sugar Shack  Jimmy Gilmer and The Fireballs  1963         1
# 1        Surfin' U.S.A.                      Beach Boys  1963         2
# 2  The End Of The World                   Skeeter Davis  1963         3
# 3    Rhythm Of The Rain                        Cascades  1963         4
# 4          He's So Fine                        Chiffons  1963         5
#
#                                           Query                Spotify Artist  \
# 0  Sugar Shack | Jimmy Gilmer and The Fireballs  Jimmy Gilmer & The Fireballs
# 1                   Surfin' U.S.A. | Beach Boys                The Beach Boys
# 2          The End Of The World | Skeeter Davis                 Skeeter Davis
# 3                 Rhythm Of The Rain | Cascades                  The Cascades
# 4                       He's So Fine | Chiffons                  The Chiffons
#
#                      Spotify Song              Spotify ID  Similarity Score  \
# 0                     Sugar Shack  2nLLenueHlqs60IcDn9lan          0.931034
# 1     Surfin' U.S.A. - Remastered  0wz1LjDb9ZNEYwOmDJ3Q4b          0.833333
# 2            The End of the World  5DTOOkooKFUvWj1XQTFa09          1.000000
# 3              Rhythm Of The Rain  7GHf8dQ2wA71wYOuRsQCZP          0.800000
# 4  He's So Fine - Remastered 2000  2Bs1Lw9LX8hBm70t1iGdlh          0.800000
#
#      0  ...  liveness loudness  mode  speechiness    tempo time_signature  \
# 0  NaN  ...     0.065   -7.484   1.0       0.0659  132.852            4.0
# 1  NaN  ...     0.112   -5.968   1.0       0.0360  159.231            4.0
# 2  NaN  ...     0.246  -10.674   1.0       0.0314   94.268            3.0
# 3  NaN  ...     0.136   -8.337   1.0       0.0441  116.634            4.0
# 4  NaN  ...     0.129   -3.265   1.0       0.0329   72.494            4.0
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/2nLLenueHlqs...  audio_features
# 1  https://api.spotify.com/v1/tracks/0wz1LjDb9ZNE...  audio_features
# 2  https://api.spotify.com/v1/tracks/5DTOOkooKFUv...  audio_features
# 3  https://api.spotify.com/v1/tracks/7GHf8dQ2wA71...  audio_features
# 4  https://api.spotify.com/v1/tracks/2Bs1Lw9LX8hB...  audio_features
#
#                                     uri  valence
# 0  spotify:track:2nLLenueHlqs60IcDn9lan    0.879
# 1  spotify:track:0wz1LjDb9ZNEYwOmDJ3Q4b    0.965
# 2  spotify:track:5DTOOkooKFUvWj1XQTFa09    0.432
# 3  spotify:track:7GHf8dQ2wA71wYOuRsQCZP    0.672
# 4  spotify:track:2Bs1Lw9LX8hBm70t1iGdlh    0.871
#
# [5 rows x 28 columns]

# %%
top100_details.columns
# Out:
# Index([      'Song Title',           'Artist',             'Year',
#                'Position',            'Query',   'Spotify Artist',
#            'Spotify Song',       'Spotify ID', 'Similarity Score',
#                         0,     'acousticness',     'analysis_url',
#            'danceability',      'duration_ms',           'energy',
#                      'id', 'instrumentalness',              'key',
#                'liveness',         'loudness',             'mode',
#             'speechiness',            'tempo',   'time_signature',
#              'track_href',             'type',              'uri',
#                 'valence'],
#       dtype='object')

# %%
## Reordering columns to match the `songs` dataframe
top100_details = top100_details[['id', 'Song Title', 'Artist', 'acousticness', 'danceability',
                                 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
                                 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature',
                                 'valence', 'Year', 'Position']]

# %%
top100_details.columns
# Out:
# Index(['id', 'Song Title', 'Artist', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'Year', 'Position'],
#       dtype='object')

# %%
top100_details.columns = ['id', 'song', 'artist', 'acousticness', 'danceability',
                 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
                  'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 
                  'valence', 'year', 'position']

# %%
songs.columns
# Out:
# Index(['id', 'song', 'artist', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'year'],
#       dtype='object')

# %%
top100_details.columns
# Out:
# Index(['id', 'song', 'artist', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'year',
#        'position'],
#       dtype='object')

# %%
top100_details.head()
# Out:
#                        id                  song  \
# 0  2nLLenueHlqs60IcDn9lan           Sugar Shack
# 1  0wz1LjDb9ZNEYwOmDJ3Q4b        Surfin' U.S.A.
# 2  5DTOOkooKFUvWj1XQTFa09  The End Of The World
# 3  7GHf8dQ2wA71wYOuRsQCZP    Rhythm Of The Rain
# 4  2Bs1Lw9LX8hBm70t1iGdlh          He's So Fine
#
#                            artist  acousticness  danceability  duration_ms  \
# 0  Jimmy Gilmer and The Fireballs         0.225         0.792     123693.0
# 1                      Beach Boys         0.661         0.550     149373.0
# 2                   Skeeter Davis         0.936         0.232     157573.0
# 3                        Cascades         0.627         0.659     146360.0
# 4                        Chiffons         0.487         0.558     112520.0
#
#    energy  instrumentalness   key  liveness  loudness  mode  speechiness  \
# 0   0.804          0.000005   7.0     0.065    -7.484   1.0       0.0659
# 1   0.854          0.000000   3.0     0.112    -5.968   1.0       0.0360
# 2   0.216          0.000005  10.0     0.246   -10.674   1.0       0.0314
# 3   0.660          0.000217   0.0     0.136    -8.337   1.0       0.0441
# 4   0.633          0.000000   7.0     0.129    -3.265   1.0       0.0329
#
#      tempo  time_signature  valence  year  position
# 0  132.852             4.0    0.879  1963         1
# 1  159.231             4.0    0.965  1963         2
# 2   94.268             3.0    0.432  1963         3
# 3  116.634             4.0    0.672  1963         4
# 4   72.494             4.0    0.871  1963         5

# %%
## Fill in the position column in the `songs` dataset with NaNs
songs['position'] = np.nan

# %%
##Drop songs that exist in top100 from the `songs` dataset
duplicates = songs[songs['id'].isin(top100_details['id'])]
songs.drop(duplicates.index, inplace=True)

# %%
##Combine the original `songs` dataset with the `top100` dataset
tracks = pd.concat([songs, top100_details])
tracks.reset_index(drop=True, inplace=True)
tracks.head()
# Out:
#                        id                  song  \
# 0  4TTV7EcfroSLWzXRY6gLv6    Alexander Hamilton
# 1  6dr7ekfhlbquvsVY8D7gyk       Aaron Burr, Sir
# 2  4cxvludVmQxryrnx1m9FqL               My Shot
# 3  0NJWhm3hUwIZSy5s0TGJ8q  The Story of Tonight
# 4  71X7bPDljJHrmEGYCe7kQ8  The Schuyler Sisters
#
#                              artist  acousticness  danceability  duration_ms  \
# 0  Original Broadway Cast Recording         0.524         0.609     236738.0
# 1  Original Broadway Cast Recording         0.271         0.646     156631.0
# 2  Original Broadway Cast Recording         0.150         0.829     333154.0
# 3  Original Broadway Cast Recording         0.835         0.407      91981.0
# 4  Original Broadway Cast Recording         0.186         0.740     186543.0
#
#    energy  instrumentalness   key  liveness  loudness  mode  speechiness  \
# 0   0.435               0.0  11.0    0.1180    -7.862   0.0        0.284
# 1   0.438               0.0   8.0    0.0945   -10.837   1.0        0.808
# 2   0.649               0.0   8.0    0.0904    -6.764   1.0        0.317
# 3   0.237               0.0   9.0    0.6480   -10.579   1.0        0.053
# 4   0.727               0.0   2.0    0.6270    -6.253   1.0        0.278
#
#      tempo  time_signature  valence  year  position
# 0  131.998             4.0    0.563  2015       NaN
# 1  160.433             4.0    0.524  2015       NaN
# 2   90.936             4.0    0.569  2015       NaN
# 3   95.111             3.0    0.612  2015       NaN
# 4  101.408             4.0    0.792  2015       NaN

# %%
tracks.shape
# Out:
# (305929, 18)

# %%
tracks['top100'] = tracks['position'].map(lambda x: 0 if pd.isnull(x) else 1)

# %%
## Total number of tracks in the top100
tracks['top100'].sum()
# Out:
# 5201

# %%
##Removing songs that are duplicated because they charted the Top 100 for multiple years
duplicates = tracks[tracks.duplicated(subset='id')]
tracks.drop(duplicates.index, inplace=True)

# %%
## Total number of tracks in the top100
tracks['top100'].sum()
# Out:
# 4517

# %%
##Duplicates defined by song name and artist name. Frame is ordered to keep the row with top100 indicator. 
duplicates = tracks[tracks.duplicated(subset=['song', 'artist'], keep=False)].sort_values(by=['song', 'top100'], ascending=False)
duplicates
# Out:
#                             id  \
# 73796   1ieiOxk5Je0GJBIscCB4H8
# 73823   3tiQdnBlEksucRa8i1lcNi
# 59299   1bBT65uYdVFeEi2rk6rKJT
# 66878   0vyQzGo4ZhrOvp0zMkpyLP
# 71320   1VlS8vBLvIHxGg8WpBX20o
# 136801  4dZfmVr4zqUYVB2GQnwAeY
# 112304  3bcKL0nHWIxWhlGswyTH60
# 137053  159yUhKZg2ZAdt0HknTqDr
# 71315   1Agu4u8a8Qm28zq5JtwaVv
# 136786  4fDMVI79jXH7S26uawPeXL
# 290876  0gNNToCW3qjabgTyBSjt3H
# 290883  52ANkSfxce4mZopSiY2StL
# 125721  1Oy02qb3UByrJhUgONgJaJ
# 150055  4gCnBqVQIC1z1ijXQqo1Oy
# 36392   3GpAQIqHto2DwOXDN0qFqJ
# 138625  4Ppy0KysTPcXyzyP5JiJDx
# 63361   0zqULZO63Ty1Md9Qo3RNDh
# 64410   484FfAR6a32EjIF8U5PVa1
# 23582   2emzZecCxUJ9cAqUNDqxyp
# 23587   2j2xdbv60inxi5rqmL5YFi
# 130980  2gVv0rV4xvUlUZNSGt0Fof
# 169142  0gROT56vsTZpVuHZI6TmIR
# 3555    1RSf4PIZomN5xGb2Arat9X
# 180932  2IZZqH4K02UIYg5EohpNHF
# 114558  6MIPvQ8kOzEf8mwrqbgUj2
# 199495  7c4FZnyekyKXIIYQUKvRb3
# 139879  3MQ9hhnd1yRMHAAb7XiW0P
# 139888  3MOBVGL2Rfb49jSpelvMcb
# 149518  4KVfBxSDMEKHtOqbOH4Izg
# 178335  5TpJKwgoXmYiKJIzCGefBF
# ...                        ...
# 211704  4pXsRou0ldzfFB18hM61Sd
# 217242  7pFydJbDEToJHtvl6g579k
# 265578  0dVabf3Sm1uHODq1vz2Lts
# 268201  2KiHyIQeBysAuz3YP0Yk3x
# 59270   4ydNaXTeV6p6MNoxZJs1hh
# 210348  40L98PfgjklCunX3Tycm48
# 223466  5OshTiUUBzCaD8N9cUysdx
# 77403   73E0RPN8zBQqQhrkBPptTX
# 199775  2w6MHwTZ5sMkuzptrwBiyI
# 253510  0Ph6AkM04RCD60P4OFJsXr
# 281420  29OEqP6K0C4VadCwRPm1YZ
# 52539   6SlKb345GYqrJSvxoT2WCs
# 298046  4vQPj9Zh7cyoeqEy8oitmz
# 103861  1I7XRxxv2AVJoQ8XkAUK6C
# 203786  5PKv8wlii7KUugkReuhLB6
# 220416  2R97RZWUx4vAFbMMtmb5Ss
# 101986  71CxuwH0zfUFf94X2UjkDs
# 145148  3VZwP7d1U7tuQjb9JZrSRF
# 216937  4rgBiyFffCCUonfTtbZoDg
# 217794  5eOzaPWJRs85vQ190tVGyB
# 101509  5Z0x77JmLkFaZOmXlaOzs8
# 102738  4aE95aFiLdGQWb4nQ7Ktut
# 199479  6RIglTkAffNXjlj5CFebWd
# 302621  5nBp8F6tekSrnFg8G2Pvug
# 232347  4XCvXkbtuPLs4bjDPpJvQW
# 1503    5HwppoQEq181ztZKGXefcV
# 72468   2xu9SqaTeSIUkX59bCaXXV
# 237426  4ZVWvCUwsOnIGmJMj71RkG
# 81033   648b848TFWWIIhusas61F7
# 101600  3rG8ZkmKHb4Ms6CsSzEITv
#
#                                                   song  \
# 73796            レット・イット・ゴー~ありのままで~ - Japanese Version
# 73823            レット・イット・ゴー~ありのままで~ - Japanese Version
# 59299                                          Überlin
# 66878                                          Überlin
# 71320                               Él Nunca Te Olvida
# 136801                              Él Nunca Te Olvida
# 112304                             ¿Quién Te Dijo Eso?
# 137053                             ¿Quién Te Dijo Eso?
# 71315                          ¿A Dónde Vamos A Parar?
# 136786                         ¿A Dónde Vamos A Parar?
# 290876                                      ¡Que Vida!
# 290883                                      ¡Que Vida!
# 125721                                      www.memory
# 150055                                      www.memory
# 36392                                         mOBSCENE
# 138625                                        mOBSCENE
# 63361                                 c u next tuesday
# 64410                                 c u next tuesday
# 23582                          [Untitled] - Remastered
# 23587                          [Untitled] - Remastered
# 130980                                            Zoom
# 169142                                            Zoom
# 3555                                            Zombie
# 180932                                          Zombie
# 114558                               Zip-A-Dee-Doo-Dah
# 199495                               Zip-A-Dee-Doo-Dah
# 139879                           Zig Zaggity Woop Woop
# 139888                           Zig Zaggity Woop Woop
# 149518                                            Zero
# 178335                                            Zero
# ...                                                ...
# 211704                          (Forever) Live And Die
# 217242                          (Forever) Live And Die
# 265578  (For God's Sake) Give More Power To The People
# 268201  (For God's Sake) Give More Power To The People
# 59270                     (Don't Go Back To) Rockville
# 210348                    (Don't Go Back To) Rockville
# 223466                    (Don't Go Back To) Rockville
# 77403                          (Don't Fear) The Reaper
# 199775                         (Don't Fear) The Reaper
# 253510                     (At Your Best) You Are Love
# 281420                     (At Your Best) You Are Love
# 52539                           (Ain't That) Good News
# 298046                          (Ain't That) Good News
# 103861                         'Til My Baby Comes Home
# 23582        0.0499  142.896             4.0   0.2050  1995       NaN       0
# 23587        0.0841   60.641             4.0   0.0215  1995       NaN       0
# 130980       0.2660  169.864             4.0   0.5330  2004       NaN       0
# 169142       0.2860  170.003             4.0   0.5310  1994       NaN       0
# 3555         0.0535  167.024             4.0   0.2330  2002       NaN       0
# 180932       0.0347  166.960             4.0   0.3060  1994       NaN       0
# 114558       0.0297  102.971             4.0   0.3590  2006       NaN       0
# 199495       0.0302  126.370             4.0   0.7520  1991       NaN       0
# 139879       0.3020  200.066             4.0   0.5810  2003       NaN       0
# 139888       0.1130  117.867             4.0   0.7510  2003       NaN       0
# 149518       0.0440  127.650             4.0   0.6610  2001       NaN       0
# 178335       0.0446  128.051             4.0   0.7520  2013       NaN       0
# ...             ...      ...             ...      ...   ...       ...     ...
# 211704       0.0280   90.180             4.0   0.8140  1988       NaN       0
# 217242       0.0297   90.179             4.0   0.8650  1986       NaN       0
# 265578       0.0307   96.889             4.0   0.8990  2006       NaN       0
# 268201       0.0574   97.814             4.0   0.4490  2001       NaN       0
# 59270        0.0301  151.991             4.0   0.9300  2011       NaN       0
# 210348       0.0343  151.659             4.0   0.9250  1988       NaN       0
# 223466       0.0337  151.496             4.0   0.8990  1984       NaN       0
# 77403        0.1050  152.754             4.0   0.3730  2010       NaN       0
# 199775       0.0524  148.170             4.0   0.6900  2009       NaN       0
# 253510       0.0385   75.610             4.0   0.3710  1976       NaN       0
# 281420       0.0413   75.659             4.0   0.3540  1999       NaN       0
# 52539        0.1280  116.382             4.0   0.9460  1960       NaN       0
# 298046       0.1090  116.478             4.0   0.9600  1964       NaN       0
# 103861       0.1710  139.564             4.0   0.8570  2007       NaN       0
# 203786       0.0724  139.529             4.0   0.9250  1989       NaN       0
# 220416       0.1830  139.663             4.0   0.8020  1985       NaN       0
# 101986       0.0300  130.822             4.0   0.3800  2007       NaN       0
# 145148       0.0283  130.620             4.0   0.4100  2001       NaN       0
# 216937       0.0336  103.531             4.0   0.1570  1986       NaN       0
# 217794       0.0336  103.531             4.0   0.1570  1986       NaN       0
# 101509       0.0369   81.743             1.0   0.2970  2015       NaN       0
# 102738       0.0367  139.801             3.0   0.3230  1997       NaN       0
# 199479       0.0360   90.438             3.0   0.3170  1991       NaN       0
# 302621       0.0274  155.697             4.0   0.9520  1982      39.0       1
# 232347       0.0289  154.549             4.0   0.8800  1981       NaN       0
# 1503         0.0344  115.497             4.0   0.4780  2010       NaN       0
# 72468        0.0333  115.520             4.0   0.4780  2010       NaN       0
# 237426       0.0336  115.474             4.0   0.4780  1974       NaN       0
# 81033        0.0472  150.014             4.0   0.6250  2009       NaN       0
# 101600       0.0505  149.937             4.0   0.7050  2007       NaN       0
#
# [24670 rows x 19 columns]

# %%
##The records to be dropped
duplicates = duplicates[duplicates.duplicated(subset=['song', 'artist'])]
tracks.drop(duplicates.index, inplace=True)

# %%
##Making sure the number of hit songs hasn't changed
tracks['top100'].sum()
# Out:
# 4517

# %%
tracks.shape
# Out:
# (291631, 19)

# %%
## Write the final dataset to CSV
tracks.to_csv('./data/tracks.csv')
